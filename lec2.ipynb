# %%
import numpy as np
print(np.__version__)
# Out:
# 2.3.5

# %%
array = np.array(10)
print(array)
# Out:
# 10

# %%
arr2 = np.array([1, 2, 3, 4, 5])
print(arr2)
# Out:
# [1 2 3 4 5]

# %%
arr3 = np.array(arr2)
print(arr3)
# Out:
# [1 2 3 4 5]

# %%
arr4 = np.array([[1, 2, 3], [4, 5, 6]])
print(arr4)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
arr5 = np.array([[1, 2, 3], [4, 5, 6]])
print(arr5)
print(arr5.shape)
# Out:
# [[1 2 3]
#  [4 5 6]]
# (2, 3)
